# %%
import pandas as pd

# %%
data = {
    "Name": ["Taloooo", "Sara", "Ahmed", "Ali"],
    "Age": [20, 22, 21, 23],
    "Marks": [85, 90, 78, 88]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age  Marks
# 0  Taloooo   20     85
# 1     Sara   22     90
# 2    Ahmed   21     78
# 3      Ali   23     88

# %%
print(df["Marks"])
# Out:
# 0    85
# 1    90
# 2    78
# 3    88
# Name: Marks, dtype: int64

# %%
print(df.loc[0])
# Out:
# Name     Taloooo
# Age           20
# Marks         85
# Name: 0, dtype: object

# %%
print(df.loc[0:2])
# Out:
#       Name  Age  Marks
# 0  Taloooo   20     85
# 1     Sara   22     90
# 2    Ahmed   21     78

# %%
print(df.iloc[1])
# Out:
# Name     Sara
# Age        22
# Marks      90
# Name: 1, dtype: object

# %%
print(df.iloc[0:2])
# Out:
#       Name  Age  Marks
# 0  Taloooo   20     85
# 1     Sara   22     90

# %%
print(df.iloc[0, 2])
# Out:
# 85

# %%
result = df[df["Marks"]>86]
print(result)
# Out:
#    Name  Age  Marks
# 1  Sara   22     90
# 3   Ali   23     88
