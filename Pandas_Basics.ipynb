# %%
import pandas as pd

# %%
data={
    "name":["Ali","Ayesha","Ahmad","Talhooo","Huda"],
    "age":[23,44,22,33,55],
    "Marks":[33,55,77,88,55]
}
df=pd.DataFrame(data)
print(df)
# Out:
#       name  age  Marks
# 0      Ali   23     33
# 1   Ayesha   44     55
# 2    Ahmad   22     77
# 3  Talhooo   33     88
# 4     Huda   55     55

# %%
print(df.head())
# Out:
#       name  age  Marks
# 0      Ali   23     33
# 1   Ayesha   44     55
# 2    Ahmad   22     77
# 3  Talhooo   33     88
# 4     Huda   55     55

# %%
print(df.head(2))
# Out:
#      name  age  Marks
# 0     Ali   23     33
# 1  Ayesha   44     55

# %%
print(df.tail())
# Out:
#       name  age  Marks
# 0      Ali   23     33
# 1   Ayesha   44     55
# 2    Ahmad   22     77
# 3  Talhooo   33     88
# 4     Huda   55     55

# %%
print(df.tail(3))
# Out:
#       name  age  Marks
# 2    Ahmad   22     77
# 3  Talhooo   33     88
# 4     Huda   55     55

# %%
print(df.shape)
# Out:
# (5, 3)

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      str
#  1   age     5 non-null      int64
#  2   Marks   5 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 252.0 bytes
# None

# %%
print(df.describe())
# Out:
#              age      Marks
# count   5.000000   5.000000
# mean   35.400000  61.600000
# std    14.117365  21.442948
# min    22.000000  33.000000
# 25%    23.000000  55.000000
# 50%    33.000000  55.000000
# 75%    44.000000  77.000000
# max    55.000000  88.000000
